# %%
# !pip install qutip
# Out:
# Collecting qutip
#   Downloading qutip-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 50.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from qutip) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from qutip) (1.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qutip) (23.1)
# Installing collected packages: qutip
# Successfully installed qutip-4.7.3

# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/qutip/__init__.py:65: UserWarning: The new version of Cython, (>= 3.0.0) is not supported.
#   warnings.warn(

# %%
def sigma_composite(N):
  #Se construyen los operadores sigma para el espacio compuesto de N qubits
  sx_list, sy_list, sz_list = [], [], []
  sm_list, sp_list= [], []
  i = 0
  for i in range(N):
    op_list = [qeye(2)] * N
    op_list[i] = sigmax()
    sx_list.append(tensor(op_list))
    op_list[i] = sigmay()
    sy_list.append(tensor(op_list))
    op_list[i] = sigmaz()
    sz_list.append(tensor(op_list))
    op_list[i] = sigmam()
    sm_list.append(tensor(op_list))
    op_list[i] = sigmap()
    sp_list.append(tensor(op_list))
  return (sx_list, sy_list, sz_list, sm_list, sp_list)

# %%
def quantum_hamiltonian():

  #Estado Inicial de Máxima Coherencia
  state_list = [(1/np.sqrt(2))*(basis(2, 0) + basis(2, 1))]*N
  state = tensor(state_list)
  ep = np.ones(N)

  #Hamiltoniano interno del sistema
  H0 = 0
  for k in range(N):
    H0 += ep[k]*sp_list[k]*sm_list[k]
  H0t = [H0 for step  in range(steps)]

  #Hamiltoniano de Interacción
  Hint = 0
  for i in range(N):
    if i ==0:
      Hint += J*(sp_list[i]*sm_list[i+1])
      Hint += J*(sp_list[i]*sm_list[N-1])
    elif i==N-1:
      Hint += J*(sp_list[i]*sm_list[i-1])
      Hint += J*(sp_list[i]*sm_list[0])
    else:
      Hint += J*(sp_list[i]*sm_list[i-1])
      Hint += J*(sp_list[i]*sm_list[i+1])

  H = H0 + Hint

  return(H, state, H0t)

# %%
#Ecuación maestra en el espacio de Liouville (Operador Liouvilliano)
def me_liouvillian(t: float, args: dict):
  out = Li.copy()
  for i in range(N):
    for j in range(N):
      if i==j:
        out += gamma*lindblad_dissipator(sm_list[j],sm_list[i])
  if N!=1:
      for i in range(N):
        if i == 0:
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[i+1])
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[N-1])
        elif i == N-1:
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[i-1])
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[0])
        else:
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[i-1])
          out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[i+1])
  return out

# %%
def eigen_system():
  M_val = []
  M_vec = []
  H_val = []
  H_vec = []

  for n in range(len(Hci[2])):
      qobjH = Qobj(Hci[2][n])
      qobjM = Qobj(DensityM[n])

      # AUTOVECTORES
      e_statesH = qobjH.eigenstates()
      e_statesM = qobjM.eigenstates(sort='high')

      # AUTOVALORES
      autovals_H = e_statesH[0]
      autovals_M = e_statesM[0]

      H_val.append(autovals_H)
      M_val.append(autovals_M)


      autovec_H = e_statesH[1]
      H_vec.append(autovec_H)
      autovec_M = e_statesM[1]
      M_vec.append(autovec_M)

  return(M_val, M_vec, H_val, H_vec)

# %% [markdown]
# \begin{align}
#     \mathcal{W}(t) = \sum_{i,j}^{2} \rho_{i} \varepsilon_{j} \left(|\langle{\rho_{i}} |{\varepsilon_{j}}\rangle|^{2} -\delta_{ij} \right).
# \end{align}

# %%
def ergotropy(graph=True):
  Erg = []
  Ut= []
  Ergo_t = 0
  for i in range(len(t)):
    for j in range(len(M_val[0])):
      for k in range(len(H_val[0])):
        if j==k:
          Ergo_t = Ergo_t + M_val[i][j]*H_val[i][k]*((((M_vec[i][j].dag())*(H_vec[i][k])).norm())**2-1)
        else:
          Ergo_t = Ergo_t + M_val[i][j]*H_val[i][k]*((((M_vec[i][j].dag())*(H_vec[i][k])).norm())**2)
    Erg.append(Ergo_t)
    Ergo_t = 0

    #Energía interna
    E = np.dot(DensityM[i],Hci[2][i])
    U = np.trace(E)
    Ut.append(U)

  return(Erg, Ut)

# %%
def efficiency():
  Eff = np.divide(Erg,Ut)
  return Eff

# %% [markdown]
# \begin{align}
#     \mathcal{C}_{l_{1}}(t) = \frac{1}{\mathcal{C}_{\max}}\sum_{i\neq j}|\rho_{ij}(t)|.
# \end{align}

# %%
def coherence():
  coherence = []
  count,cohe = 0,0
  for n in range(len(t)):
    for i in range(len(DensityM[0][:])):
      for j in range(len(DensityM[0][:])):
        if i!=j:
          count +=1
          cohe += abs(DensityM[n][i,j])
    coherence.append(cohe)
    cohe = 0

  return coherence

# %% [markdown]
# \begin{align}
#         E(t) = \frac{1}{\mathcal{N}_{\{i,j\}}}\sum_{\{i,j\}}\mathcal{C}_{i  j}(t)
# \end{align}

# %%
def concurrence_t():
  Ctotal = []

  cte = 1/(N)

  for n in range(len(t)):
    Csum = 0
    for i in range(N):
        if i==0:
          Csum += concurrence(DensityM[n].ptrace([i,i+1]))
        elif i==N-1:
          Csum += concurrence(DensityM[n].ptrace([N-1,0]))
        else:
          Csum += concurrence(DensityM[n].ptrace([i,i+1]))

    Ctotal.append(Csum)

  return (np.multiply(cte,Ctotal),cte, N)

# %%
#Calculo para un número N fijo
N = 4
gamma = float(input("Gamma: "))
steps = 3500
t = np.linspace(0, 250, steps)

gamma_i = gamma/2
ep = 1
J = 2 * gamma
sx_list, sy_list, sz_list, sm_list, sp_list = sigma_composite(N)

#Hci = (H,state,H0t)
Hci = quantum_hamiltonian()
Li = liouvillian(Hci[0],[])
DensityM = qutip.mesolve(me_liouvillian, Hci[1], t).states
# Out:
# Gamma: 0.1

# %%
fig , ax = plt.subplots(figsize=(5,4))
ax.set_title(r'Poblaciones $J=2\Gamma$ ',fontsize = 12 )

for n in range(len(DensityM[0][:])):
  val = str(n+1) * 2
  ax.plot(t, np.real(np.array(DensityM)[:, n, n]),linewidth=2, label= fr'$\rho_{{{val}}}(t)$', alpha= 0.5)

# %%
#Eigensystem, Ergotropy
M_val, M_vec, H_val, H_vec = eigen_system()
Erg, Ut = ergotropy()

# %%
#Gráficas de autovalores de la matriz densidad
fig , ax = plt.subplots(figsize=(5,4))
ax.set_title(r'AUTOVALORES $J=2\Gamma$ ',fontsize = 12 )

for i in range(len(M_val[0])):
  variable = str(i+1) + "-" + str(i+1)
  ax.plot(t, [np.real(lista[i]) for lista in M_val],linewidth=2, label= fr'$\rho_{{{variable}}}(t)$')
    #ax.legend()
ax.set_xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
fig, ax = plt.subplots(figsize=(5,4))
ax.set_title('ENERGÍA',fontsize = 12 )
ax.plot(gamma*t,Ut,linewidth=1,label=r"Energía Interna ${U}(t)$")
ax.plot(gamma*t,Erg,linewidth=1,label=r"Ergotropía $\mathcal{E}(t)$")
ax.set_xscale('log')
ax.set_xlim(0.001,15)
ax.legend()
ax.set_xlabel(r"$\Gamma t$")
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# [1.9999999999999998, 1.9715593102276463, 1.943369977294156, 1.9154335248217096, 1.8877389527574913, 1.860283587887421, 1.8330600317771684, 1.8060696238602065, 1.7793020653290017, 1.7527578047081256, 1.7264295596228993, 1.7003127483621179, 1.6744078340771487, 1.6487096348264165, 1.6232142851335394, 1.5979241520188625, 1.5728289144569596, 1.5479281450609677, 1.5232188169816796, 1.4987010818267374, 1.4743751089878514, 1.450240941050606, 1.4262976656650075, 1.4025444857514042, 1.378980526738341, 1.3556052307635167, 1.3324180460558595, 1.3094186008131992, 1.2866066074490154, 1.2639818634966993, 1.241544279503243, 1.2192938153649109, 1.1972305274658377, 1.1753545153440204, 1.1536659461386942, 1.1321650279509567, 1.1108520125592707, 1.0897271855105792, 1.0687908594948423, 1.0480433700891703, 1.027485066558717, 1.0071162772138267, 0.9869373539582837, 0.9669486638056858, 0.9471505697194338, 0.9275434264183149, 0.9081275762785128, 0.8889770578740854, 0.8701106393399121, 0.8514442363438038, 0.8329779592253815, 0.8147118815281627, 0.7966460379760607, 0.7787804226463995, 0.7611149873520286, 0.7436496402207016, 0.726384244466008, 0.7093186173454311, 0.6924525292970622, 0.6759456754463393, 0.6597452816172942, 0.6437514180145976, 0.6279634036005737, 0.6123805061790013, 0.5970019430343054, 0.5818268816760161, 0.5668544406815608, 0.5520836906304638, 0.5375136551230449, 0.5231433118767588, 0.5089715938934196, 0.4949973906905996, 0.48219722901570605, 0.46989408519751624, 0.45777787093918354, 0.44584654851481176, 0.43409807863390926, 0.42253042090381476, 0.41114153433718087, 0.39992937790013083, 0.3888919110967284, 0.37802709458549827, 0.36733289022669524, 0.3568072511323461, 0.3464481407960673, 0.33625353119831813, 0.3262213989351711, 0.31634972594154004, 0.30663650021942584, 0.2970797165678828, 0.2876773773115362, 0.27842749302466685, 0.26932808324799684, 0.2603771771955216, 0.25157281444886154, 0.2429130456367884, 0.23439593309775808, 0.2260195515234286, 0.2182181339247044, 0.21054984312845987, 0.20300707558748146, 0.1955880011293874, 0.18845623348438914, 0.18168823256349026, 0.17504007176764577, 0.16850981416941888, 0.16209554893266195, 0.1557953913254541, 0.14960748271309968, 0.1435299905311964, 0.13790199455565924, 0.13303750155044602, 0.1282635927652215, 0.12357854715678482, 0.11898067716288371, 0.1148629723579835, 0.11111003798731274, 0.10743400537689804, 0.10383326578440925, 0.100306245449754, 0.09685140486078482, 0.09346723802820864, 0.09015227176989601, 0.08690506500480774, 0.08372420784670728, 0.08060831787607178, 0.07755604498344501, 0.07456606967755346, 0.0716371011990918, 0.06876787687650526, 0.06595716149285863, 0.06320374666397141, 0.060506450227969355, 0.057864115646394314, 0.05527561141698967, 0.05273983049825974, 0.050255689745881287, 0.0478280673561972, 0.04572709065242822, 0.04366938016349586, 0.041653995282926154, 0.03968001737216648, 0.037746549213652586, 0.035852714477304204, 0.033997657200250726, 0.032180541279577035, 0.030400549977881667, 0.02865688544142073, 0.027209921880147835, 0.026223835101824668, 0.025267055889526692, 0.024338774531086575, 0.023438202784373696, 0.022564573337923742, 0.021717139283447456, 0.020895173600051022, 0.020097968650001116, 0.019324835685863646, 0.01857510436884191, 0.017848122298140638, 0.01714325455117596, 0.016612882364434995, 0.01611623794588062, 0.01563456765924017, 0.0151674179443647, 0.014714348925318643, 0.014274933937520889, 0.013848758310518485, 0.013435420541031536, 0.013034531574375159, 0.01264571413202612, 0.012268602361064147, 0.011902841493548422, 0.01154808751558311, 0.011204006845826614, 0.010870276023203233, 0.010546581403582103, 0.01023261886519308, 0.009928093522549185, 0.009632719448657399, 0.009346219405296547, 0.009068324581148236, 0.008798774337573683, 0.008537315961830506, 0.008283704427526196, 0.008037702162116921, 0.007799078821254943, 0.007567611069799405, 0.007343082369306125, 0.007125282771817351, 0.00691400871977608, 0.006709062851893398, 0.0065102538148033625, ...

# %%
Eff = efficiency()
fig, ax = plt.subplots(figsize=(5,4))
ax.set_title('Eficiencia $J=2\Gamma$',fontsize = 12 )
ax.plot(gamma*t,Eff,linewidth=1.2,label=f"Eficiencia ")
ax.set_xscale('log')
ax.set_xlabel(r"$\Gamma t$")
ax.legend()

# %%
Coherence_t = coherence()

# %%
fig, ax = plt.subplots()
ax.plot(gamma*t,np.multiply(1/max(Coherence_t),Coherence_t))
ax.set_xscale('log')
# Out:
# (-0.001, 1.5)

# %%
concurrencia_t = concurrence_t()
fig, ax = plt.subplots()
ax.plot(gamma*t,concurrencia_t[0])
ax.set_title('Concurrencia')
ax.set_xscale('log')
# Out:
# (0.001, 10)
