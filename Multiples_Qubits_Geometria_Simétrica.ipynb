# %%
# !pip install qutip
# Out:
# Collecting qutip
#   Downloading qutip-4.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 73.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.10/dist-packages (from qutip) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from qutip) (1.11.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from qutip) (23.1)
# Installing collected packages: qutip
# Successfully installed qutip-4.7.3

# %%
from qutip import *
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/qutip/__init__.py:65: UserWarning: The new version of Cython, (>= 3.0.0) is not supported.
#   warnings.warn(

# %%
def sigma_composite(N):
  #Se construyen los operadores sigma para el espacio compuesto de N qubits
  sx_list, sy_list, sz_list = [], [], []
  sm_list, sp_list= [], []
  i = 0
  for i in range(N):
    op_list = [qeye(2)] * N
    op_list[i] = sigmax()
    sx_list.append(tensor(op_list))
    op_list[i] = sigmay()
    sy_list.append(tensor(op_list))
    op_list[i] = sigmaz()
    sz_list.append(tensor(op_list))
    op_list[i] = sigmam()
    sm_list.append(tensor(op_list))
    op_list[i] = sigmap()
    sp_list.append(tensor(op_list))
  return (sx_list, sy_list, sz_list, sm_list, sp_list)

# %%
def quantum_hamiltonian():

  #Estado inicial de Maximo Entrelazamiento (Estado de Bell)
  #state_list = [bell_state(state='11')]*int(np.sqrt(N))

  # Estado Inicial de Máxima Coherencia
  state_list = [(1/np.sqrt(2))*(basis(2, 0) + basis(2, 1))]*N
  state = tensor(state_list)
  ep = np.ones(N)

  #Hamiltoniano interno del sistema
  H0 = 0
  for k in range(N):
    H0 += ep[k]*sp_list[k]*sm_list[k]
  H0t = [H0 for step  in range(steps)]

  #Hamiltoniano de Interacción
  Hint = 0
   for n in range(N):
    for m in range(N):
      if n!=m:
       Hint += J*(sp_list[n]*sm_list[m])

  H = H0 + Hint

  return(H, state, H0t)

# %%
#Ecuación maestra en el espacio de Liouville (Operador Liouvilliano)
def me_liouvillian(t: float, args: dict):
  out = Li.copy()
  for i in range(N):
    for j in range(N):
      if i==j:
        out += gamma*lindblad_dissipator(sm_list[j],sm_list[i])
  i,j=0,0
  for i in range(N):
    for j in range(N):
      if i!=j:
        out += gamma_i*lindblad_dissipator(sm_list[i],sm_list[j])
  return out

# %%
def eigen_system(graph=True):
  M_val = []
  M_vec = []
  H_val = []
  H_vec = []

  for n in range(len(Hci[2])):
      qobjH = Qobj(Hci[2][n])
      qobjM = Qobj(DensityM[n])

      # AUTOVECTORES
      e_statesH = qobjH.eigenstates()
      e_statesM = qobjM.eigenstates(sort='high')

      # AUTOVALORES
      autovals_H = e_statesH[0]
      autovals_M = e_statesM[0]

      H_val.append(autovals_H)
      M_val.append(autovals_M)

      autovec_H = e_statesH[1]
      H_vec.append(autovec_H)
      autovec_M = e_statesM[1]
      M_vec.append(autovec_M)

  return(M_val, M_vec, H_val, H_vec)

# %% [markdown]
# \begin{align}
#     \mathcal{W}(t) = \sum_{i,j}^{2} \rho_{i} \varepsilon_{j} \left(|\langle{\rho_{i}} |{\varepsilon_{j}}\rangle|^{2} -\delta_{ij} \right).
# \end{align}

# %%
def ergotropy():
  Erg = []
  Ut= []
  Ergo_t = 0
  i,j,k = 0,0,0
  for i in range(len(t)):
    for j in range(len(M_val[0])):
      for k in range(len(H_val[0])):
        if j==k:
          Ergo_t = Ergo_t + M_val[i][j]*H_val[i][k]*((((M_vec[i][j].dag())*(H_vec[i][k])).norm())**2-1)
        else:
          Ergo_t = Ergo_t + M_val[i][j]*H_val[i][k]*((((M_vec[i][j].dag())*(H_vec[i][k])).norm())**2)
    Erg.append(Ergo_t)
    Ergo_t = 0

    #Energía interna
    E = np.dot(DensityM[i],Hci[2][i])
    U = np.trace(E)
    Ut.append(U)

  return(Erg, Ut)

# %%
def efficiency(qubits = None):
  Eff = np.divide(Erg,Ut)
  return Eff

# %% [markdown]
# \begin{align}
#     \mathcal{C}_{l_{1}}(t) = \frac{1}{\mathcal{C}_{\max}}\sum_{i\neq j}|\rho_{ij}(t)|.
# \end{align}

# %%
def coherence():
  coherence = []
  count,cohe = 0,0
  for n in range(len(t)):
    for i in range(len(DensityM[0][:])):
      for j in range(len(DensityM[0][:])):
        if i!=j:
          count +=1
          cohe += abs(DensityM[n][i,j])
    coherence.append(cohe)
    cohe = 0


  return coherence

# %% [markdown]
# \begin{align}
#         E(t) = \frac{1}{\mathcal{N}_{\{i,j\}}}\sum_{\{i,j\}}\mathcal{C}_{i  j}(t)
# \end{align}

# %%
def concurrence_t():
  Ctotal = []
  conex = 0
  for i in range(N - 1):
    for j in range(N-1, i, -1):
      conex +=1

  cte = 1/(conex)

  for n in range(len(t)):
    Csum = 0
    for i in range(N-1):
      for j in range(N-1,i,-1):
        Csum += concurrence(DensityM[n].ptrace([i,j]))
    Ctotal.append(Csum)

  return np.multiply(cte,Ctotal)

# %%
#Calculo para un número N fijo
N = 4
gamma = float(input("Gamma: "))
steps = 3500
t = np.linspace(0, 250, steps)

gamma_i = gamma/2
ep = 1
J = 2 * gamma
sx_list, sy_list, sz_list, sm_list, sp_list = sigma_composite(N)

Hci = quantum_hamiltonian()
Li = liouvillian(Hci[0],[])
DensityM = qutip.mesolve(me_liouvillian, Hci[1], t).states
# Out:
# Gamma: 0.1

# %%
fig , ax = plt.subplots(figsize=(5,4))
ax.set_title(r'Poblaciones $J=2\Gamma$ ',fontsize = 12 )

for n in range(len(DensityM[0][:])):
  val = str(n+1) * 2
  ax.plot(t, np.real(np.array(DensityM)[:, n, n]),linewidth=2, label= fr'$\rho_{{{val}}}(t)$', alpha= 0.5)

# %%
M_val, M_vec, H_val, H_vec = eigen_system()
Erg, Ut = ergotropy()

# %%
#Gráficas de autovalores de la matriz densidad
fig , ax = plt.subplots(figsize=(5,4))
ax.set_title(r'AUTOVALORES $J=2\Gamma$ ',fontsize = 12 )

for i in range(len(M_val[0])):
  variable = str(i+1) + "-" + str(i+1)
  ax.plot(t, [np.real(lista[i]) for lista in M_val],linewidth=2, label= fr'$\rho_{{{variable}}}(t)$')
    #ax.legend()
ax.set_xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
fig, ax = plt.subplots(figsize=(5,4))
ax.set_title('ENERGÍA',fontsize = 12 )
ax.plot(gamma*t,Ut,label=r"Energía Interna ${U}(t)$")
ax.plot(gamma*t,Erg,label=r"Ergotropía $\mathcal{E}(t)$")
ax.set_xscale('log')
ax.set_xlim(0.001,15)
ax.legend()
ax.set_xlabel(r"$\Gamma t$")
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# [1.9999999999999998, 1.971454096074044, 1.942955846101801, 1.9145165110013205, 1.8861346859480899, 1.8578171725904082, 1.82956577469824, 1.801432125518439, 1.773396013091431, 1.745470610111436, 1.7176586790961097, 1.6899656555764568, 1.6624031297469901, 1.6349746302980779, 1.607684700538976, 1.5805458567643393, 1.5535529748751313, 1.5273725426339642, 1.5018475421857227, 1.4765408579338413, 1.4514517440882, 1.4265794081721663, 1.4019218713464543, 1.377477452689471, 1.353244434179084, 1.329221630217806, 1.3054079313226146, 1.281802548463915, 1.258404869273299, 1.2352144553593036, 1.2122310733460662, 1.189454602385428, 1.1668850926180845, 1.144522687335585, 1.1223676509875644, 1.1004203282846916, 1.0786811432749, 1.057150581667002, 1.035829177893539, 1.014717505608233, 0.9938161524400444, 0.9731256843366497, 0.9526467159643092, 0.9323798652806685, 0.913532309034526, 0.8949516321844083, 0.8766036212639732, 0.8584867290561397, 0.840599423816632, 0.8229401844553169, 0.8055074961727459, 0.7882998464019702, 0.7713157211406803, 0.7545536016149407, 0.7380119612888927, 0.7216892632024965, 0.7055839576270364, 0.6897061464395422, 0.6741693915313969, 0.6588502271885851, 0.6437469327093946, 0.6288577651644565, 0.6141809589410349, 0.5997147255017958, 0.5854572533441729, 0.5714067081464567, 0.5575612330867222, 0.5439189493207477, 0.530477956605253, 0.5172363340529788, 0.5041921410063825, 0.4913434180170582, 0.4786881879183387, 0.4662244569789925, 0.45395021612633085, 0.44186344222756885, 0.4299620994187948, 0.41824414047141867, 0.4067075081865801, 0.3953501368085219, 0.38416995344855065, 0.37316487951179145, 0.36233282444308845, 0.3516716878007501, 0.3412373726773937, 0.3312060432958361, 0.32133405701832923, 0.31161929690370466, 0.30205965638160237, 0.29265304015951743, 0.2833973651006949, 0.27429056107002875, 0.2653305717454826, 0.25651535539303544, 0.2478428856035021, 0.23931115198996017, 0.23161125406032906, 0.2244219299577753, 0.21736323719989753, 0.21043295857196156, 0.20362890719303767, 0.19694892664835648, 0.19039089108877633, 0.18395270529797264, 0.17763230472804636, 0.17142765550444666, 0.16561696172967447, 0.15996736912338194, 0.15442935091312776, 0.14900085687617723, 0.14367986968857302, 0.1384644047725704, 0.13335251011888105, 0.12834226608517693, 0.1234317851723415, 0.11861921177990845, 0.11390272194214034, 0.10928052304615198, 0.10475085353347065, 0.10031198258638771, 0.09596220980040993, 0.09169986484408824, 0.087523307107454, 0.08425916151304388, 0.08108259418509234, 0.0779736478128108, 0.07493091991042658, 0.07195303822222077, 0.06903866010007197, 0.06618647188794316, 0.06350962229715225, 0.06095157767692886, 0.05844881930258256, 0.05600016570442474, 0.05360446223356862, 0.05126058044588176, 0.04896741749676843, 0.04672389554689877, 0.0445289611789715, 0.04238158482557499, 0.0402807602081889, 0.038225503787348826, 0.03621485422397506, 0.0342478718518504, 0.03232363816121118, 0.03044125529340185, 0.028599845546529345, 0.026798550892033254, 0.025036532502085786, 0.023756796192995446, 0.022781557217153914, 0.021834982379001423, 0.020916270804364905, 0.02002464377993102, 0.01915934415844572, 0.01831963577801182, 0.017504802895296042, 0.016714149632449785, 0.016118837365151906, 0.015624895423243997, 0.015146342216896789, 0.014682691676565674, 0.014233473164684885, 0.013798230993108654, 0.013376523954747374, 0.012967924789358645, 0.012572018646265563, 0.012188404666051533, 0.011816695170822615, 0.01145651482585969, 0.01110750024913353, 0.010769299632670745, 0.01044157237545034, 0.010123988727522452, 0.009816229445042707, 0.009517985455922752, 0.009228957535802652, 0.008948855994056046, 0.008677400369546178, 0.008414319135855304, 0.008159349415716395, 0.007912236704383102, 0.007672734601677304, 0.00744060455246186, 0.00721561559529108, 0.00699754411899777, 0.006786173626980029, 0.006581294508959597, 0.0063827038199860825, 0.006190205066469402, 0.006003607999027953, 0.005822728411943853, 0.005647387949024974, 0.005477413915676502, 0.0 ...

# %%
Eff = efficiency()
fig, ax = plt.subplots(figsize=(5,4))
ax.set_title('Eficiencia $J=2\Gamma$',fontsize = 12 )
ax.plot(gamma*t,Eff,label="Eficiencia ")
ax.set_xscale('log')
ax.set_xlabel(r"$\Gamma t$")
ax.legend()

# %%
Coherence_t = coherence()

# %%
fig, ax = plt.subplots()
ax.plot(gamma*t,np.multiply(1/max(Coherence_t),Coherence_t))
ax.set_xscale('log')
# Out:
# (-0.001, 1.5)

# %%
concurrencia_t = concurrence_t()

fig, ax = plt.subplots()
ax.plot(gamma*t,concurrencia_t)
ax.set_title('Concurrencia')
ax.set_xscale('log')
# Out:
# [<matplotlib.axis.YTick at 0x7b3d8a1a2530>,
#  <matplotlib.axis.YTick at 0x7b3d8a1c2470>,
#  <matplotlib.axis.YTick at 0x7b3d8a1c3340>,
#  <matplotlib.axis.YTick at 0x7b3d8a053bb0>]
